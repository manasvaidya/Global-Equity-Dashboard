# %% [markdown]
# ## Code

# %%
################################################## Post Processing ################################################

df.drop(columns = ['Sector', 'sector_codes_mod', 'Breadth (%) 90d Past', 'Rel to 200Day (%) 90d Past', 
                   'A/D Line 90d Past', 'Return on Equity (%) Z-Score', 'Net Profit Margin (%) Z-Score', 
                   'Operating Margin (%) Z-Score'], 
        inplace=True)
df.rename(columns = {'sector_codes': 'Sector Code'}, inplace=True)




df.T.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_b4e1a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Sector</th>
#       <th id="T_b4e1a_level0_col0" class="col_heading level0 col0" >Technology</th>
#       <th id="T_b4e1a_level0_col1" class="col_heading level0 col1" >Financials</th>
#       <th id="T_b4e1a_level0_col2" class="col_heading level0 col2" >Consumer Discretionary</th>
#       <th id="T_b4e1a_level0_col3" class="col_heading level0 col3" >Industrials</th>
#       <th id="T_b4e1a_level0_col4" class="col_heading level0 col4" >Healthcare</th>
#       <th id="T_b4e1a_level0_col5" class="col_heading level0 col5" >Consumer Staples</th>
#       <th id="T_b4e1a_level0_col6" class="col_heading level0 col6" >Energy</th>
#       <th id="T_b4e1a_level0_col7" class="col_heading level0 col7" >Basic Materials</th>
#       <th id="T_b4e1a_level0_col8" class="col_heading level0 col8" >Telecom</th>
# ...
